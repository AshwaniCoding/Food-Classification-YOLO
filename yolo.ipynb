# %% [markdown]
# # For Checking GPU

# %%
# !nvidia-smi
# Out:
# Mon Aug 26 06:21:36 2024
# +---------------------------------------------------------------------------------------+
# | NVIDIA-SMI 535.104.05             Driver Version: 535.104.05   CUDA Version: 12.2     |
# |-----------------------------------------+----------------------+----------------------+
# | GPU  Name                 Persistence-M | Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp   Perf          Pwr:Usage/Cap |         Memory-Usage | GPU-Util  Compute M. |
# |                                         |                      |               MIG M. |
# |=========================================+======================+======================|
# |   0  Tesla T4                       Off | 00000000:00:04.0 Off |                    0 |
# | N/A   34C    P8               9W /  70W |      0MiB / 15360MiB |      0%      Default |
# |                                         |                      |                  N/A |
# ...

# %% [markdown]
# # For Mounting the Google Drive

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # For Installing Ultralytics Library

# %%
# !pip install ultralytics

# %% [markdown]
# # For Importing YOLO Algorithm from Ultralytics

# %%
from ultralytics import YOLO

from IPython.display import display, Image

# %% [markdown]
# # For Changing the Drive Path

# %%
# %cd /content/drive/MyDrive/Food Classification YOLO
# Out:
# /content/drive/MyDrive/Food Classification YOLO

# %% [markdown]
# # For Training the model

# %%
# !yolo task=detect mode=train model=yolov8m.pt data=data.yaml epochs=25 imgsz=224 plots=True
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# ...

# %% [markdown]
# # For Predicting a single Image

# %%
# !yolo predict model="/content/drive/MyDrive/Food Classification YOLO/runs/detect/train2/weights/best.pt" source='YOLO/test/images/ch40.jpg'
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,844,392 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/1 /content/drive/MyDrive/Food Classification YOLO/YOLO/test/images/ch40.jpg: 192x224 1 Chapati, 69.8ms
# Speed: 1.1ms preprocess, 69.8ms inference, 590.2ms postprocess per image at shape (1, 3, 192, 224)
# Results saved to runs/detect/predict2
# 💡 Learn more at https://docs.ultralytics.com/modes/predict

# %% [markdown]
# # For Validating the Model

# %%
# !yolo task=detect mode=val model="/content/drive/MyDrive/Food Classification YOLO/runs/detect/train2/weights/best.pt" data="data.yaml"
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,844,392 parameters, 0 gradients, 78.7 GFLOPs
# val: Scanning /content/drive/MyDrive/Food Classification YOLO/YOLO/valid/labels.cache... 570 images, 6 backgrounds, 0 corrupt: 100% 576/576 [00:00<?, ?it/s]
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100% 36/36 [00:15<00:00,  2.33it/s]
#                    all        576        673      0.933      0.873      0.931      0.745
#              Apple Pie         60         60      0.964      0.892       0.96      0.695
#            Butter Naan         75        134      0.863       0.59        0.8      0.526
#            Dal Makhani         70         70      0.971      0.986      0.995       0.83
#          Kadhai Paneer         80         80      0.957      0.975      0.992      0.806
# ...

# %% [markdown]
# # For Testing/Predicting a set of Images

# %%
# !yolo task=detect mode=predict model="/content/drive/MyDrive/Food Classification YOLO/runs/detect/train2/weights/best.pt" conf=0.25 source=realTest
# Out:
# Ultralytics YOLOv8.2.82 🚀 Python-3.10.12 torch-2.3.1+cu121 CUDA:0 (Tesla T4, 15102MiB)
# Model summary (fused): 218 layers, 25,844,392 parameters, 0 gradients, 78.7 GFLOPs
#
# image 1/3 /content/drive/MyDrive/Food Classification YOLO/realTest/ApplePie.jpg: 128x224 1 Apple Pie, 117.5ms
# image 2/3 /content/drive/MyDrive/Food Classification YOLO/realTest/Idli.jpg: 128x224 1 Idli, 12.4ms
# image 3/3 /content/drive/MyDrive/Food Classification YOLO/realTest/Jalebi_1080x.webp: 224x224 1 Jalebi, 13.4ms
# Speed: 1.0ms preprocess, 47.8ms inference, 169.4ms postprocess per image at shape (1, 3, 224, 224)
# Results saved to runs/detect/predict3
# 💡 Learn more at https://docs.ultralytics.com/modes/predict
